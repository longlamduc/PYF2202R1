# %% [markdown]
# # Function

# %%
# Viết chương trình nhập vào tên của 3 học viên khác nhau và in ra tên của 3 học viên đó.
name1 = input("nhập tên 1: ")
name2 = input("nhập tên 2: ")
name3 = input("nhập tên 3: ")
print("tên 3 người là:",name1,",", name2,",", name3)
# Out:
# nhập tên 1: Long
# nhập tên 2: Thiện
# nhập tên 3: Trung
# tên 3 người là: Long , Thiện , Trung

# %%
for i in range(3):
    ten = str(input(f"Nhập tên học viên {i+1}:"))
    print(ten)
# Out:
# Nhập tên học viên 1:Long
# Long
# Nhập tên học viên 2:Thiện
# Thiện
# Nhập tên học viên 3:TRung
# TRung

# %%
# Viết chương trình nhập vào tên của 3 học viên khác nhau và in ra tên của 3 học viên đó, 
# sau đó cho biết tên dài nhất có bao nhiêu ký tự

# %%
a = 0
for i in range(3):
    ten = str(input(f"Nhập tên học viên {i+1}: "))
    print(ten)
    if len(ten) > a:
        a = len(ten)
print(f"Tên dài nhất có {a} kí tự")
# Out:
# Nhập tên học viên 1: Long
# Long
# Nhập tên học viên 2: Thiện
# Thiện
# Nhập tên học viên 3: Trung
# Trung
# Tên dài nhất có 5 kí tự

# %% [markdown]
# ## Function(hàm) là gì?

# %% [markdown]
# Hàm (function) là một khối lệnh đặc biệt, nó được đặt tên, giúp mã chương trình dễ đọc hơn, và có thể gọi để sử dụng ở các nơi khác nhau trong chương trình. Hàm chính là khối lệnh có thể tái sử dụng (reuseable).

# %% [markdown]
# ### Hàm
#
# Cú pháp:
#
# `def <tên hàm>(<tham số>):
#     //Nội dung hàm`
#
# Gọi hàm:
# `<tên hàm>(<giá trị đầu vào>)`

# %% [markdown]
# ### Ví dụ: Hàm in

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### Ví dụ: Hàm tính giá trị tuyệt đối

# %%
abs(-2)
# Out:
# 2

# %% [markdown]
# ### Ví dụ: Hàm vẽ hình tròn

# %%
import turtle
pen = turtle.Turtle()
pen.circle(100)
turtle.done()

# %% [markdown]
# ## Xây dựng và sử dụng hàm trong python

# %% [markdown]
# ### Hàm say_hello

# %%
# Tạo ra một hàm say_hello() để in "Hello World" ra màn hình
def say_hello():
    print("Hello World")

# %%
say_hello()
# Out:
# Hello World

# %% [markdown]
# ### Hàm vẽ cây thông

# %%
import turtle

def ve_cay_thong():
    pen = turtle.Turtle()

    pen.speed(9)

    # ve la cay

    pen.pencolor("#21610B")

    pen.fillcolor("#21610B")
    pen.begin_fill()

    pen.right(180)
    pen.goto(0,40)
    pen.circle(50, steps = 3)
    pen.end_fill()

    pen.penup()
    pen.goto(0,10)
    pen.pendown()

    pen.fillcolor("#21610B")
    pen.begin_fill()


    pen.circle(50, steps = 3)
    pen.end_fill()

    pen.penup()
    pen.goto(0,-20)
    pen.pendown()

    pen.fillcolor("#21610B")
    pen.begin_fill()


    pen.circle(50, steps = 3)
    pen.end_fill()

    # ve than cay
    pen.penup()
    pen.goto(19,-95)
    pen.pendown()

    pen.pencolor("#886A08")

    pen.fillcolor("#886A08")
    pen.begin_fill()

    pen.left(90)

    pen.forward(100)
    pen.right(90)
    pen.forward(40)
    pen.right(90)
    pen.forward(100)
    pen.right(90)
    pen.forward(40)

    pen.end_fill()


    turtle.done()

# %%
ve_cay_thong()

# %% [markdown]
# ### Thực hành: Viết hàm vẽ ra hình ảnh như dưới đây:
# ![image.png](attachment:image.png)

# %%
import turtle

def draw_circles():
    size = 10
    pen = turtle.Turtle()
    for i in range(6):
        pen.circle(size)
        pen.penup()
        pen.rt(90)
        pen.fd(20)
        pen.lt(90)
        pen.pendown()
        size += 20
    turtle.done()

# %%
draw_circles()

# %% [markdown]
# ## doc_string cho hàm

# %%
# Hàm tính chu vi hình chữ nhật
def calc_rectangle_perimeter():
    '''Hàm này dùng để tính chu vi của hình chữ nhật.'''
    pass

# %%
calc_rectangle_perimeter.__doc__
# Out:
# 'Hàm này dùng để tính chu vi của hình chữ nhật.'

# %%
help(abs)
# Out:
# Help on built-in function abs in module builtins:
#
# abs(x, /)
#     Return the absolute value of the argument.

# %%
# Hàm xếp loại học sinh
# Viết hàm nhập vào điểm trung bình của học sinh và in ra học lực của học sinh đó theo quy tắc sau:
# - Nếu trung bình >= 8 => Học sinh giỏi
# - Nếu trung bình >= 5 => Học sinh khá
# - Ngược lại => Học sinh trung bình
def hoc_luc():
    average_mark = float(input("Nhập điểm trung bình: "))
    
    if average_mark >= 8:
        print("Học sinh giỏi")
    elif average_mark >= 5:
        print("Học sinh khá")
    else:
        print("Học sinh trung bình")
        
hoc_luc()
# Out:
# Nhập điểm trung bình: 4
# Học sinh trung bình

# %% [markdown]
# ## Phạm vi biến

# %%
'''
Những biến số được tạo ra bên trong hàm thì chỉ có thể truy cập và sử dụng bên trong hàm.
Khi hàm kết thúc thì biến sẽ bị xóa đi.
'''
# Hàm tính tổng các số từ 1 đến 10
def calc_sum_1_to_10():
    tong = 0
    for i in range(11):
        tong += i
    print(tong)

calc_sum_1_to_10()
print(tong)
# Out:
# 55
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20840/3101636120.py in <module>
#       7
#       8 calc_sum_1_to_10()
# ----> 9 print(tong)
#
# NameError: name 'tong' is not defined

# %%
day = 22

def print_day():
    day = 23
    print(day)

# %%
print_day()
# Out:
# 23

# %%
print(day)
# Out:
# 22

# %% [markdown]
# ## Đối số của hàm

# %%
# Hàm tính thể tích hình lập phương
def calc_cube_volume(side):
    volume = side ** 3
    print(volume)
    
calc_cube_volume(5)
# Out:
# 125

# %%
# Hàm xếp loại học sinh
# Viết hàm nhập vào điểm trung bình của học sinh và in ra học lực của học sinh đó theo quy tắc sau:
# - Nếu trung bình >= 8 => Học sinh giỏi
# - Nếu trung bình >= 5 => Học sinh khá
# - Ngược lại => Học sinh trung bình

def calc_average_mark(ave_mark):
    if ave_mark >= 8:
        print('Học sinh giỏi')
    elif ave_mark >= 5:
        print('Học sinh khá')
    else:
        print('Học sinh trung bình')
        
calc_average_mark(4.5)
# Out:
# Học sinh trung bình

# %% [markdown]
# ### Thực hành: Viết hàm nhận vào một số nguyên và kiểm tra xem số đó có phải là số nguyên tố hay không.

# %%
def is_prime_number(number):
    flag = True
    
    for i in range(2, number):
        if not number % i:
            flag = False
            break
            
    if flag:
        print(f"{number} là số nguyên tố")
    else:
        print(f"{number} không phải là số nguyên tố")
        
is_prime_number(11)
# Out:
# 11 là số nguyên tố

# %% [markdown]
# ## Đối số có giá trị mặc định

# %% [markdown]
# Viết hàm greetings() nhận vào `name` và `sentence`, sau đó in ra câu chào tương ứng

# %%
# greetings("Long", "how it's going") -> Hello Long, how it's going?
def greetings(name, sentence="how it's going"):
    print(f"Hello {name}, {sentence}?")

greetings("Long")
# Out:
# Hello Long, how it's going?

# %%
print('abc', end='-')
print('def')
# Out:
# abc-def

# %% [markdown]
# ## Giá trị trả về của hàm

# %% [markdown]
# # return
#
# Cú pháp:
#
# `return <giá trị trả về>`
#
# ##### Lưu ý: Sau khi thực hiện lệnh return, chương trình sẽ thoát khỏi hàm ngay lập tức (những lệnh sau đó không được thực hiện)
#
# Ví dụ:
#
# Hãy viết 1 hàm trả về giá trị trung bình của 2 số bất kỳ

# %%
def calc_average(num1, num2):
    average = (num1 + num2) / 2
    return average
    
result = calc_average(3, 5)
print(result)
# Out:
# 4.0

# %%
# Hàm tính chiều dài của chuỗi
# Viết hàm string_len(string) nhận vào một `string` và trả về độ dài của `string` đó
def string_len(string):
    return len(string)

content = "Module and Function"
print(string_len(content))
# Out:
# 19

# %%
# Hàm tính giai thừa
# Viết hàm calc_factorial(num) nhận vào một số `num` và trả về giai thừa của nó
def calc_factorial(num):
    if num == 0 or num == 1:
        return 1
    else:
        result = 1
        for i in range(2, num + 1):
            result *= i
            
        return result
    
print(calc_factorial(4))
# Out:
# 24

# %%
# Hàm kiểm tra năm nhuận
# Viết hàm is_leap_year(year) nhận vào một giá trị năm `year` và trả về True nếu `year` là năm nhuận, ngược lại trả về False
def is_leap_year(year):
    if year % 400 == 0 or (year % 4 == 0 and year % 100 != 0):
        return True
    return False

print(is_leap_year(3000))
# Out:
# False
